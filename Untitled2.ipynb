# %%
# Ejemplo de Integer
tamaño_muestra = 150
print("El tamaño de muestra es ", tamaño_muestra)
# Out:
# El tamaño de muestra es  150

# %%
nombre="Miguel 'Happy' Lora"

# %%
nombre
# Out:
# "Miguel 'Happy' Lora"

# %%
a=10.
type(a)
# Out:
# float

# %%
b=int(a)
type(b)
# Out:
# int

# %%
a=float(input("Ingrese el numero a"))
# Out:
# Ingrese el numero a 3.2

# %%
b=float( input("Ingrese el numero b") )
# Out:
# Ingrese el numero b 4.1

# %%
print("La suma de a con b es a+b=", a+b)
# Out:
# La suma de a con b es a+b= 7.3

# %%
9%2 == 0
# Out:
# False

# %%
(4,9,16)

# %%
from math import sqrt 

sqrt(9)
# Out:
# 3.0

# %%
sqrt(16)
# Out:
# 4.0

# %%
sqrt((4,9,16))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sqrt((4,9,16))
#
# TypeError: must be real number, not tuple

# %%
for x in (4,9,16): 
    print( sqrt(x) )
# Out:
# 2.0
# 3.0
# 4.0

# %%
from math import *

# %%
import math

# %%
math.sin(math.pi/2)
# Out:
# 1.0
